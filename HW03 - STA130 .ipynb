# %% [markdown]
# Question 2:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the penguins dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv'
penguins = pd.read_csv(url)

# Filter out rows with missing flipper_length_mm values
penguins = penguins.dropna(subset=['flipper_length_mm'])

# Create subplots for each species
species_list = penguins['species'].unique()
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Loop through each species and create a KDE plot
for i, species in enumerate(species_list):
    species_data = penguins[penguins['species'] == species]
    
    # Plot KDE for flipper_length_mm using fill=True
    sns.kdeplot(
        species_data['flipper_length_mm'], 
        ax=axes[i], 
        fill=True,  # Updated here
        color="b"
    )
    
    # Add title to each subplot
    axes[i].set_title(f'{species} Flipper Length KDE')
    
    # Add labels
    axes[i].set_xlabel('Flipper Length (mm)')
    if i == 0:
        axes[i].set_ylabel('Density')

# Adjust

# %% [markdown]
# Question 2 ChatBot Session: https://chatgpt.com/share/66f58d7b-8e50-8007-80f0-eb252692f150

# %% [markdown]
# Question 3:

# %% [markdown]
# In my opion i think i'd prefer histograms after asking chatgpt and looking at the other options. The main reason why is because i find the shape of the distribution the most straightforward when having to look at data. For example, when comparing it to the KDE plots histograms are able to show alot more of the finer details within the dataset whereas a KDE plot kind of just shows the overall image and in a way smooths out the finer details (sometimes). To add on I also find the flexibility of histograms to be very good. this is because its very easy to adjust bin sizes for example when making the physical plots which can help make the plots look overall better giving a more detailed view when compared to other plots.

# %% [markdown]
# Chatbot session link: https://chatgpt.com/share/66f590e2-a39c-8007-8339-0b5554b0b225

# %% [markdown]
# Question 4:

# %%
from scipy import stats
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

n = 1500
data1 = stats.uniform.rvs(0, 10, size=n)
data2 = stats.norm.rvs(5, 1.5, size=n)
data3 = np.r_[stats.norm.rvs(2, 0.25, size=int(n/2)), stats.norm.rvs(8, 0.5, size=int(n/2))]
data4 = stats.norm.rvs(6, 0.5, size=n)

fig = make_subplots(rows=1, cols=4)

fig.add_trace(go.Histogram(x=data1, name='A', nbinsx=30, marker=dict(line=dict(color='black', width=1))), row=1, col=1)
fig.add_trace(go.Histogram(x=data2, name='B', nbinsx=15, marker=dict(line=dict(color='black', width=1))), row=1, col=2)
fig.add_trace(go.Histogram(x=data3, name='C', nbinsx=45, marker=dict(line=dict(color='black', width=1))), row=1, col=3)
fig.add_trace(go.Histogram(x=data4, name='D', nbinsx=15, marker=dict(line=dict(color='black', width=1))), row=1, col=4)

fig.update_layout(height=300, width=750, title_text="Row of Histograms")
fig.update_xaxes(title_text="A", row=1, col=1)
fig.update_xaxes(title_text="B", row=1, col=2)
fig.update_xaxes(title_text="C", row=1, col=3)
fig.update_xaxes(title_text="D", row=1, col=4)
fig.update_xaxes(range=[-0.5, 10.5])

for trace in fig.data:
    trace.xbins = dict(start=0, end=10)
    
# This code was produced by just making requests to Microsoft Copilot
# https://github.com/pointOfive/stat130chat130/blob/main/CHATLOG/wk3/COP/SLS/0001_concise_makeAplotV1.md

fig.show(renderer='png') # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS

# %% [markdown]
# 4.1: Datasets B and D have similair means and somehwat similair variences
#
# 4.2: B and A have similair means but different variances
#
# 4.3: C and A both have high variences but very different means
#
# 4.4: C and D have different means and variences

# %% [markdown]
# Question 6:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the fast food nutrition dataset
url = "https://raw.githubusercontent.com/manuelamc14/fast-food-Nutritional-Database/main/Tables/nutrition.csv"
df = pd.read_csv(url)

# Plot 1: Distribution of Calories
fig1 = plt.figure(figsize=(10, 6))
plt.hist(df['calories'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Calories in Fast Food Items')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.grid(True)
# Save the figure as a PNG file
fig1.savefig('calories_distribution.png')

# Plot 2: Calories from Fat vs Total Calories
fig2 = plt.figure(figsize=(10, 6))
plt.scatter(df['calories'], df['calories from fat'], alpha=0.6, color='orange')
plt.title('Calories vs Calories from Fat')
plt.xlabel('Total Calories')
plt.ylabel('Calories from Fat')
plt.grid(True)
# Save the figure as a PNG file
fig2.savefig('calories_vs_fat.png')

# Plot 3: Boxplot of Macronutrient Content
fig3 = plt.figure(figsize=(10, 6))
df[['total fat (g)', 'carbohydrates (g)', 'protein (g)']].plot(kind='box')
plt.title('Boxplot of Macronutrient Content (Fat, Carbohydrates, Protein)')
plt.ylabel('Grams')
plt.grid(True)
# Save the figure as a PNG file
fig3.savefig('macronutrient_boxplot.png')

# Optionally, display the figures
plt.show()

# %% [markdown]
# The histogram helps show the calorie distrubtion across the fastfood items. The scatterplot shows the calories dervied from fat in the foods. Finally, the boxplot helps visualize the variation in fats, carbohydrates and protein across the dataset.

# %%
import pandas as pd

# Load the fast food nutrition dataset
url = "https://raw.githubusercontent.com/manuelamc14/fast-food-Nutritional-Database/main/Tables/nutrition.csv"
df = pd.read_csv(url)

# Displaying summary statistics of the dataset
summary_statistics = df.describe()
print(summary_statistics)
# Out:
#        restaurant id  category id    item id  serving size (oz)     calories  \
# count     750.000000   750.000000  750.00000         395.000000   750.000000
# mean     2126.666667   113.685333  374.50000          10.612996   296.149333
# std       897.234043     9.956229  216.65064           7.286159   209.034366
# min      1000.000000   100.000000    0.00000           0.035274     0.000000
# 25%      1000.000000   106.000000  187.25000           5.200000   150.000000
# 50%      2000.000000   111.000000  374.50000          10.158912   260.000000
# 75%      3000.000000   123.000000  561.75000          16.000000   410.000000
# max      3000.000000   130.000000  749.00000          32.000000  1880.000000
#
#        calories from fat  total fat (% daily value)  saturated fat (g)  \
# count         260.000000                 260.000000         637.000000
# mean          127.096154                  21.815385           3.409105
# ...

# %% [markdown]
# Above are the summary statistics of the data. This helps give the exact numerical values for the data shown within the plots above it.
#
# chatgpt session link: https://chatgpt.com/share/66f5aab6-2bbc-8007-9cd0-f1a0c0556b71
